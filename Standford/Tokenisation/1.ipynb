# %% [markdown]
# ## Tokenisation

# %%
text = "Hey there I am Silky!"
code = list(text.encode('utf-8'))

# %%
code
# Out:
# [72,
#  101,
#  121,
#  32,
#  116,
#  104,
#  101,
#  114,
#  101,
#  32,
#  73,
#  32,
#  97,
#  109,
#  32,
#  83,
#  105,
#  108,
#  107,
#  121,
#  33]

# %%
print(len(text))
print(len(code))
# Out:
# 21
# 21

# %%
tokens = text.encode("utf-8")
tokens = list(map(int, tokens))
tokens
# Out:
# [72,
#  101,
#  121,
#  32,
#  116,
#  104,
#  101,
#  114,
#  101,
#  32,
#  73,
#  32,
#  97,
#  109,
#  32,
#  83,
#  105,
#  108,
#  107,
#  121,
#  33]

# %%
def byte_pair_encoding(v):
    counts = {}
    for pair in zip(v, v[1: ]):
        counts[pair] = counts.get(pair, 0) + 1
    return counts

text = "Unicode (also known as The Unicode Standard and TUS[1][2]) is a character encoding standard maintained by the Unicode Consortium designed to support the use of text in all of the world's writing systems that can be digitized. Version 17.0[A] defines 159,801 characters and 172 scripts[3] used in various ordinary, literary, academic and technical contexts. Unicode has largely supplanted the previous environment of myriad incompatible character sets used within different locales and on different computer architectures. The entire repertoire of these sets, plus many additional characters, were merged into the single Unicode set. Unicode is used to encode the vast majority of text on the Internet, including most web pages, and relevant Unicode support has become a common consideration in contemporary software development. Unicode is ultimately capable of encoding more than 1.1 million characters. The Unicode character repertoire is synchronized with ISO/IEC 10646, each being code-for-code identical with one another. However, The Unicode Standard is more than just a repertoire within which characters are assigned. To aid developers and designers, the standard also provides charts and reference data, as well as annexes explaining concepts germane to various scripts, providing guidance for their implementation. Topics covered by these annexes include character normalization, character composition and decomposition, collation, and directionality.[4]"

tokens = list(text.encode("utf-8"))

code = byte_pair_encoding(tokens)

print(sorted(((v, k) for k, v in code.items()), reverse=True))
# Out:
# [(46, (101, 32)), (28, (115, 32)), (28, (101, 114)), (27, (99, 111)), (26, (32, 97)), (24, (100, 101)), (24, (100, 32)), (24, (97, 110)), (23, (97, 114)), (22, (105, 110)), (22, (32, 99)), (21, (116, 101)), (21, (114, 101)), (21, (111, 110)), (20, (32, 116)), (19, (116, 104)), (16, (110, 32)), (16, (104, 101)), (15, (116, 105)), (15, (111, 100)), (15, (105, 99)), (15, (104, 97)), (15, (99, 104)), (14, (110, 116)), (14, (44, 32)), (14, (32, 115)), (14, (32, 105)), (13, (110, 105)), (13, (110, 100)), (13, (105, 116)), (13, (105, 111)), (12, (116, 32)), (12, (114, 97)), (12, (111, 114)), (12, (101, 110)), (11, (101, 115)), (11, (101, 100)), (11, (99, 116)), (11, (97, 99)), (11, (32, 100)), (10, (110, 101)), (10, (110, 99)), (10, (100, 105)), (10, (85, 110)), (10, (32, 119)), (10, (32, 111)), (9, (117, 115)), (9, (115, 101)), (9, (97, 108)), (9, (46, 32)), (9, (32, 109)), (9, (32, 85)), (8, (115, 105)), (8, (114, 32)), (8, (110, 103)), (8,
, (115, 115)), (1, (115, 91)), (1, (114, 110)), (1, (114, 108)), (1, (114, 99)), (1, (114, 46)), (1, (114, 45)), (1, (114, 44)), (1, (112, 117)), (1, (112, 109)), (1, (112, 105)), (1, (111, 116)), (1, (111, 108)), (1, (111, 99)), (1, (110, 121)), (1, (110, 118)), (1, (110, 109)), (1, (110, 46)), (1, (109, 121)), (1, (109, 115)), (1, (109, 109)), (1, (109, 32)), (1, (108, 116)), (1, (108, 100)), (1, (107, 110)), (1, (106, 117)), (1, (106, 111)), (1, (105, 117)), (1, (105, 108)), (1, (105, 98)), (1, (105, 97)), (1, (104, 114)), (1, (104, 110)), (1, (103, 117)), (1, (103, 108)), (1, (103, 105)), (1, (102, 116)), (1, (102, 105)), (1, (101, 98)), (1, ...

# %%
chr(101), chr(32)
# Out:
# ('e', ' ')

# %%
top_pair = max(code, key=code.get)
top_pair
# Out:
# (101, 32)

# %%
def merge(v, pair, idx):
    new_v = []
    i = 0
    while i<len(v):
        if i < len(v) - 1 and v[i] == pair[0] and v[i+1] == pair[1]:
            new_v.append(idx)
            i+=2
        else:
            new_v.append(v[i])
            i+=1
    return new_v


print(merge([5, 6, 6, 7, 9, 1], (6, 6), 99))
# Out:
# [5, 99, 7, 9, 1]

# %%
text = "Unicode (also known as The Unicode Standard and TUS[1][2]) is a character encoding standard maintained by the Unicode Consortium designed to support the use of text in all of the world's writing systems that can be digitized. Version 17.0[A] defines 159,801 characters and 172 scripts[3] used in various ordinary, literary, academic and technical contexts. Unicode has largely supplanted the previous environment of myriad incompatible character sets used within different locales and on different computer architectures. The entire repertoire of these sets, plus many additional characters, were merged into the single Unicode set. Unicode is used to encode the vast majority of text on the Internet, including most web pages, and relevant Unicode support has become a common consideration in contemporary software development. Unicode is ultimately capable of encoding more than 1.1 million characters. The Unicode character repertoire is synchronized with ISO/IEC 10646, each being code-for-code identical with one another. However, The Unicode Standard is more than just a repertoire within which characters are assigned. To aid developers and designers, the standard also provides charts and reference data, as well as annexes explaining concepts germane to various scripts, providing guidance for their implementation. Topics covered by these annexes include character normalization, character composition and decomposition, collation, and directionality.[4]"

tokens = list(text.encode("utf-8"))

code = byte_pair_encoding(tokens)

print(sorted(((v, k) for k, v in code.items()), reverse=True))
# Out:
# [(46, (101, 32)), (28, (115, 32)), (28, (101, 114)), (27, (99, 111)), (26, (32, 97)), (24, (100, 101)), (24, (100, 32)), (24, (97, 110)), (23, (97, 114)), (22, (105, 110)), (22, (32, 99)), (21, (116, 101)), (21, (114, 101)), (21, (111, 110)), (20, (32, 116)), (19, (116, 104)), (16, (110, 32)), (16, (104, 101)), (15, (116, 105)), (15, (111, 100)), (15, (105, 99)), (15, (104, 97)), (15, (99, 104)), (14, (110, 116)), (14, (44, 32)), (14, (32, 115)), (14, (32, 105)), (13, (110, 105)), (13, (110, 100)), (13, (105, 116)), (13, (
(49, 55)), (2, (49, 32)), (2, (32, 104)), (2, (32, 103)), (2, (32, 83)), (2, (32, 73)), (1, (122, 97)), (1, (121, 115)), (1, (121, 114)), (1, (121, 110)), (1, (121, 46)), (1, (120, 112)), (1, (119, 114)), (1, (119, 111)), (1, (119, 110)), (1, (119, 104)), (1, (119, 97)), (1, (117, 116)), (1, (117, 114)), (1, (117, 109)), (1, (117, 108)), (1, (117, 105)), (1, (116, 119)), (1, (116, 117)), (1, (116, 44)), (1, (115, 115)), (1, (115, 91)), (1, (114, 110)), (1, (114, 108)), (1, (114, 99)), (1, (114, 46)), (1, (114, 45)), (1, (114, 44)), (1, (112, 117)), (1, (112, 109)), (1, (112, 105)), (1, (111, 116)), (1, (111, 108)), (1, (111, 99)), (1, (110, 121)), (1, (110, 118)), (1, (110, 109)), (1, (110, 46)), (1, (109, 121)), (1, (109, 115)), (1, (109, 109)), (1, (109, 32)), (1, (108, 116)), (1, (108, 100)), (1, (107, 110)), (1, (106, 117)), (1, (106, 111)), (1, (105, 117)), (1, (105, 108)), (1, (105, 98)), (1, (105, 97)), (1, (104, 114)), (1, (104, 110)), (1, (103, 117)), (1, (103, 108)), (1, (103, 105)), (1, (102, 116)), (1, (102, 105)), (1, (101, 98)), (1, ...

# %%
def byte_pair_encoding(v):
    counts = {}
    for pair in zip(v, v[1: ]):
        counts[pair] = counts.get(pair, 0) + 1
    return counts

def merge(v, pair, idx):
    new_v = []
    i = 0
    while i<len(v):
        if i < len(v) - 1 and v[i] == pair[0] and v[i+1] == pair[1]:
            new_v.append(idx)
            i+=2
        else:
            new_v.append(v[i])
            i+=1
    return new_v

vocab_size = 276
num_merges = vocab_size - 256
ids = list(tokens)
merges = {}
for i in range(num_merges):
    bpe = byte_pair_encoding(ids)
    pair = max(bpe, key=bpe.get)
    idx = 256 + i
    print(f"Merging {pair} into new token {idx}")
    ids = merge(ids, pair, idx)
    merges[pair] = idx

print("Token length:", len(tokens))
print("ids length:", len(ids))
print(f"Compression ratio: {len(tokens) / len(ids):.2f}X")
# Out:
# Merging (101, 32) into new token 256
# Merging (115, 32) into new token 257
# Merging (101, 114) into new token 258
# Merging (99, 111) into new token 259
# Merging (97, 110) into new token 260
# Merging (100, 32) into new token 261
# Merging (97, 114) into new token 262
# Merging (105, 110) into new token 263
# Merging (116, 104) into new token 264
# Merging (111, 110) into new token 265
# Merging (259, 100) into new token 266
# Merging (99, 104) into new token 267
# Merging (116, 105) into new token 268
# Merging (44, 32) into new token 269
# Merging (266, 256) into new token 270
# Merging (116, 258) into new token 271
# Merging (101, 110) into new token 272
# Merging (111, 114) into new token 273
# Merging (116, 32) into new token 274
# Merging (110, 105) into new token 275
# Token length: 1464
# ids length: 1077
# Compression ratio: 1.36X

# %%
vocab = {idx: bytes([idx]) for idx in range(256)}
for (p0, p1), idx in merges.items():
    vocab[idx] = vocab[p0] + vocab[p1]
    
def decode(ids):
    tokens = b"".join(vocab[idx] for idx in ids)
    text = tokens.decode("utf-8", errors="replace")
    return text

print(decode([72, 101, 108, 108, 111]))
# Out:
# Hello

# %%
print(merges.get((110, 105)))
# Out:
# 275

# %%
        code = byte_pair_encoding(tokens)
        code
# Out:
# {(85, 110): 10,
#  (110, 105): 13,
#  (105, 99): 15,
#  (99, 111): 27,
#  (111, 100): 15,
#  (100, 101): 24,
#  (101, 32): 46,
#  (32, 40): 1,
#  (40, 97): 1,
#  (97, 108): 9,
#  (108, 115): 2,
#  (115, 111): 4,
#  (111, 32): 7,
#  (32, 107): 1,
#  (107, 110): 1,
#  (110, 111): 3,
#  (111, 119): 2,
#  (119, 110): 1,
#  (110, 32): 16,
#  (32, 97): 26,
#  (97, 115): 7,
#  (115, 32): 28,
#  (32, 84): 7,
#  (84, 104): 4,
#  (104, 101): 16,
#  (32, 85): 9,
#  (32, 83): 2,
#  (83, 116): 2,
#  (116, 97): 7,
#  (97, 110): 24,
#  (110, 100): 13,
#  (100, 97): 6,
#  (97, 114): 23,
#  (114, 100): 5,
#  (100, 32): 24,
#  (84, 85): 1,
#  (85, 83): 1,
#  (83, 91): 1,
#  (91, 49): 1,
#  (49, 93): 1,
#  (93, 91): 1,
#  (91, 50): 1,
#  (50, 93): 1,
#  (93, 41): 1,
#  (41, 32): 1,
#  (32, 105): 14,
#  (105, 115): 5,
#  (97, 32): 3,
#  (32, 99): 22,
#  (99, 104): 15,
#  (104, 97): 15,
#  (114, 97): 12,
#  (97, 99): 11,
#  (99, 116): 11,
#  (116, 101): 21,
#  (101, 114): 28,
#  (114, 32): 8,
#  (32, 101): 7,
#  (101, 110): 12,
#  (110, 99): 10,
#  (100, 105): 10,
#  (105, 110): 22,
#  (110, 103): 8,
#  (103, 32): 7,
#  (32, 115): 14,
#  (115, 116): 6,
#  (32, 109): 9,
#  (109, 97): 6,
#  (97, 105): 4,
#  (110, 116): 14,
#  (110, 101): 10,
#  (101, 100): 11,
#  (32, 98): 5,
#  (98, 121): 2,
#  (121, 32): 7,
#  (32, 116): 20,
#  (116, 104): 19,
#  (32, 67): 1,
#  (67, 111): 1,
#  (111, 110): 21,
#  (110, 115): 2,
#  (111, 114): 12,
#  (114, 116): 7,
#  (116, 105): 15,
#  (105, 117): 1,
#  (117, 109): 1,
#  (109, 32): 1,
#  (32, 100): 11,
#  (101, 115): 11,
#  (115, 105): 8,
#  (105, 103): 4,
#  (103, 110): 3,
#  (116, 111): 7,
#  (115, 117): 3,
#  (117, 112): 3,
#  (112, 112): 3,
#  (112, 111): 5,
#  (116, 32): 12,
#  (32, 117): 5,
#  (117, 115): 9,
#  (115, 101): 9,
#  (32, 111): 10,
#  (111, 102): 7,
#  (102, 32): 6,
#  (101, 120): 6,
#  (120, 116): 3,
#  (108, 108): 4,
#  (108, 32): 5,
#  (32, 119): 10,
#  (119, 111): 1,
#  (114, 108): 1,
#  (108, 100): 1,
#  (100, 39): 1,
#  (39, 115): 1,
#  (119, 114): 1,
#  (114, 105): 7,
#  (105, 116): 13,
#  (115, 121): 2,
#  (121, 115): 1,
#  (101, 109): 4,
#  (109, 115): 1,
#  (97, 116): 8,
#  (99, 97): 6,
#  (98, 101): 3,
#  (103, 105): 1,
#  (105, 122): 3,
#  (122, 101): 2,
#  (100, 46): 2,
#  (46, 32): 9,
#  (32, 86): 1,
#  (86, 101): 1,
#  (114, 115): 7,
#  (105, 111): 13,
#  (32, 49): 5,
#  (49, 55): 2,
#  (55, 46): 1,
#  (46, 48): 1,
#  (48, 91): 1,
#  (91, 65): 1,
#  (65, 93): 1,
#  (93, 32): 2,
#  (101, 102): 2,
#  (102, 105): 1,
#  (49, 53): 1,
#  (53, 57): 1,
#  (57, 44): 1,
#  (44, 56): 1,
#  (56, 48): 1,
#  (48, 49): 1,
#  (49, 32): 2,
#  (55, 50): 1,
#  (50, 32): 1,
#  (115, 99): 2,
#  (99, 114): 2,
#  (105, 112): 2,
#  (112, 116): 3,
#  (116, 115): 7,
#  (115, 91): 1,
#  (91, 51): 1,
#  (51, 93): 1,
#  (32, 118): 3,
#  (118, 97): 4,
#  (111, 117): 3,
#  (110, 97): 3,
#  (114, 121): 3,
#  (121, 44): 2,
#  (44, 32): 14,
#  (32, 108): 3,
#  (108, 105): 4,
#  (97, 100): 3,
#  (109, 105): 2,
#  (99, 32): 1,
#  (101, 99): 5,
#  (104, 110): 1,
#  (115, 46): 3,
#  (32, 104): 2,
#  (108, 97): 4,
#  (114, 103): 2,
#  (103, 101): 4,
#  (101, 108): 6,
#  (108, 121): 2,
#  (112, 108): 4,
#  (32, 112): 5,
#  (112, 114): 3,
#  (114, 101): 21,
#  (101, 118): 5,
#  (118, 105): 4,
#  (110, 118): 1,
#  (105, 114): 7,
#  (114, 111): 4,
#  (110, 109): 1,
#  (109, 101): 5,
#  (109, 121): 1,
#  (121, 114): 1,
#  (105, 97): 1,
#  (111, 109): 6,
#  (109, 112): 6,
#  (112, 97): 3,
#  (105, 98): 1,
#  (98, 108): 2,
#  (108, 101): 6,
#  (101, 116): 4,
#  (119, 105): 4,
#  (104, 105): 4,
#  (105, 102): 2,
#  (102, 102): 2,
#  (102, 101): 3,
#  (108, 111): 3,
#  (111, 99): 1,
#  (112, 117): 1,
#  (117, 116): 1,
#  (114, 99): 1,
#  (116, 117): 1,
#  (117, 114): 1,
#  (32, 114): 5,
#  (101, 112): 4,
#  (112, 101): 4,
#  (111, 105): 3,
#  (115, 44): 5,
#  (108, 117): 3,
#  (110, 121): 1,
#  (100, 100): 1,
#  (119, 101): 4,
#  (103, 108): 1,
#  (116, 46): 2,
#  (97, 106): 1,
#  (106, 111): 1,
#  (116, 121): 2,
#  (32, 73): 2,
#  (73, 110): 1,
#  (114, 110): 1,
#  (116, 44): 1,
#  (99, 108): 2,
#  (117, 100): 2,
#  (109, 111): 4,
#  (111, 115): 3,
#  (101, 98): 1,
#  (98, 32): 1,
#  (97, 103): 1,
#  (109, 109): 1,
#  (105, 100): 6,
#  (102, 116): 1,
#  (116, 119): 1,
#  (119, 97): 1,
#  (118, 101): 4,
#  (111, 112): 3,
#  (112, 109): 1,
#  (117, 108): 1,
#  (108, 116): 1,
#  (105, 109): 2,
#  (97, 112): 1,
#  (97, 98): 1,
#  (49, 46): 1,
#  (46, 49): 1,
#  (105, 108): 1,
#  (121, 110): 1,
#  (104, 114): 1,
#  (104, 32): 4,
#  (73, 83): 1,
#  (83, 79): 1,
#  (79, 47): 1,
#  (47, 73): 1,
#  (73, 69): 1,
#  (69, 67): 1,
#  (67, 32): 1,
#  (49, 48): 1,
#  (48, 54): 1,
#  (54, 52): 1,
#  (52, 54): 1,
#  (54, 44): 1,
#  (101, 97): 1,
#  (101, 105): 2,
#  (101, 45): 1,
#  (45, 102): 1,
#  (102, 111): 2,
#  (114, 45): 1,
#  (45, 99): 1,
#  (111, 116): 1,
#  (114, 46): 1,
#  (32, 72): 1,
#  (72, 111): 1,
#  (114, 44): 1,
#  (32, 106): 1,
#  (106, 117): 1,
#  (119, 104): 1,
#  (115, 115): 1,
#  (84, 111): 2,
#  (111, 118): 3,
#  (99, 101): 3,
#  (97, 44): 1,
#  (110, 110): 2,
#  (120, 101): 2,
#  (120, 112): 1,
#  (32, 103): 2,
#  (114, 109): 2,
#  (103, 117): 1,
#  (117, 105): 1,
#  (32, 102): 1,
#  (110, 46): 1,
#  (112, 105): 1,
#  (99, 115): 1,
#  (32, 110): 1,
#  (122, 97): 1,
#  (110, 44): 3,
#  (111, 108): 1,
#  (121, 46): 1,
#  (46, 91): 1,
#  (91, 52): 1,
#  (52, 93): 1}

# %%
def encode(text):
    tokens = list(text.encode("utf-8"))
    while len(tokens) >= 2:
        code = byte_pair_encoding(tokens)
        pair = min(code, key =  lambda p : merges.get(p, float("inf")))
        if pair not in merges:
            break
        idx = merges[pair]
        tokens = merge(tokens, pair, idx)
    return tokens

print(encode("h"))
# Out:
# [104]

# %%
print(decode(encode("Hello world")))
# Out:
# Hello world

# %%
test_text = """Unicode (also known as The Unicode Standard and TUS[1][2]) is a character encoding standard maintained by the Unicode Consortium designed to support the use of text in all of the world's writing systems that can be digitized. Version 17.0[A] defines 159,801 characters and 172 scripts[3] used in various ordinary, literary, academic and technical contexts.

Unicode has largely supplanted the previous environment of myriad incompatible character sets used within different locales and on different computer architectures. The entire repertoire of these sets, plus many additional characters, were merged into the single Unicode set. Unicode is used to encode the vast majority of text on the Internet, including most web pages, and relevant Unicode support has become a common consideration in contemporary software development. Unicode is ultimately capable of encoding more than 1.1 million characters."""
print(decode(encode(test_text)) == test_text)
# Out:
# True
